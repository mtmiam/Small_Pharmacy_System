# %%
from tkinter import *
from tkinter import messagebox
import pymysql 

#insert the drug
def insert():

    Label(window,text="insert all drug's data",width=45,height=1).pack()
    var1label=Label(window,text='Code',bg='#6495ED',width=15)
    var1label.pack()
    global var1
    var1=StringVar()
    var1Entry=Entry(window,textvariable=var1,width=30).pack()
    Label(window, text="",bg="#093545")
    var2label=Label(window,text='Name',bg='#6495ED',width=15)
    var2label.pack()
    global var2
    var2=StringVar()
    var2Entry=Entry(window,textvariable=var2,width=30).pack()
    var3label=Label(window,text='Quantity',bg='#6495ED',width=15)
    var3label.pack()
    global var3
    var3=StringVar()
    var3Entry=Entry(window,textvariable=var3,width=30).pack()
    var4label=Label(window,text='Category',bg='#6495ED',width=15)
    var4label.pack()
    global var4
    var4=StringVar()
    var4Entry=Entry(window,textvariable=var4,width=30).pack()
    var5label=Label(window,text='ExpirayDate',bg='#6495ED',width=15)
    var5label.pack()
    global var5
    var5=StringVar()
    var5Entry=Entry(window,textvariable=var5,width=30).pack()
    var6label=Label(window,text='Price',bg='#6495ED',width=15)
    var6label.pack()
    global var6
    var6=StringVar()
    var6Entry=Entry(window,textvariable=var6,width=30).pack()
    def inserting():
        con=pymysql.connect(host='localhost',user='root',password="",database='testdb')
        cur=con.cursor()
        cur.execute("INSERT INTO drug (Code,Name,Quantity,Category,ExpirayDate,Price) VALUES (%s, %s, %s,%s,%s,%s)",
        (var1.get(),var2.get(),var3.get(),var4.get(),var5.get(),var6.get()))
        con.commit()
    storButton = Button(window, text="store", command=inserting,background='#3CB371').pack()
    window.mainloop()




#searching the drug
def search():

    Label(window,text='search for a drug ',width=45,height=1).pack()
    Label(window, text="",bg="#093545").pack()
    drugnamelable=Label(window,text='enter drug name',background='#7AC5CD',width=15)
    drugnamelable.pack()
    Label(window, text="",bg="#093545").pack()
    global drugname
    drugname=StringVar()
    drugnameEntry=Entry(window,textvariable=drugname,width=30).pack()
    Label(window, text="",bg="#093545").pack()
    def searching():
        try:
            con=pymysql.connect(host='localhost',user='root',password="",database='testdb')
            cur=con.cursor()
            cur.execute("select * from  drug where Name=%s",(drugname.get()))
            row=cur.fetchone()
            w4=Tk()
            w4.geometry('300x250')
            w4.configure(bg = "#093545")
            w4.title('searching')
            Label(w4,text="Code, Name, Quntity, Category, ExpirayDate, Price",bg='#7AC5CD').pack()
            Label(w4,text="",bg="#093545").pack()
            Label(w4,text=f'{row} ',width=45,height=1).pack()
            if row==None:
                messagebox.showerror('error',f"not found")
        except Exception as ex:
            messagebox.showerror('error',f"error due to: {str(ex)}")
    searchButton = Button(window, text="search", command=searching,background='#3CB371').pack()
    window.mainloop()





#Employee

def Employee():
  Label(window,text="insert all employee's data",width=45,height=1).pack()
  var7label=Label(window,text='National_ID',bg='#6495ED',width=15)
  var7label.pack()
  global var7
  var7=StringVar()
  var7Entry=Entry(window,textvariable=var7,width=30).pack()

  Label(window, text="",bg="#093545")
  var8label=Label(window,text='Name',bg='#6495ED',width=15)
  var8label.pack()
  global var8
  var8=StringVar()
  var8Entry=Entry(window,textvariable=var8,width=30).pack()

  var9label=Label(window,text='Address',bg='#6495ED',width=15)
  var9label.pack()
  global var9
  var9=StringVar()
  var9Entry=Entry(window,textvariable=var9,width=30).pack()

  var10label=Label(window,text='Phone Number',bg='#6495ED',width=15)
  var10label.pack()
  global var10
  var10=StringVar()
  var10Entry=Entry(window,textvariable=var10,width=30).pack()

  var11label=Label(window,text='Salary',bg='#6495ED',width=15)
  var11label.pack()
  global var11
  var11=StringVar()
  var11Entry=Entry(window,textvariable=var11,width=30).pack()

  var12label=Label(window,text='Shift Time',bg='#6495ED',width=15)
  var12label.pack()
  global var12
  var12=StringVar()
  var12Entry=Entry(window,textvariable=var12,width=30).pack()

  var13label=Label(window,text='Pharmacy Branch',bg='#6495ED',width=15)
  var13label.pack()
  global var13
  var13=StringVar()
  var13Entry=Entry(window,textvariable=var13,width=30).pack()

  def insertingEmployee():
      con=pymysql.connect(host='localhost',user='root',password="",database='testdb')
      cur=con.cursor()
      cur.execute("INSERT INTO employee (National_ID,Name,Address,PhoneNumber,Salary,ShiftTime,PharmacyBranch) VALUES (%s, %s, %s,%s,%s,%s,%s)",
      (var7.get(),var8.get(),var9.get(),var10.get(),var11.get(),var12.get(),var13.get()))
      con.commit()
  storeButton = Button(window, text="store", command=insertingEmployee,background='#3CB371').pack()
  window.mainloop()       



#Patient

def Patient():
   Label(window,text="insert patient's data",width=45,height=1).pack()

   var14label=Label(window,text='National_ID',bg='#6495ED',width=15)
   var14label.pack()
   global var14
   var14=StringVar()
   var14Entry=Entry(window,textvariable=var14,width=30).pack()

   Label(window, text="",bg="#093545")
   var15label=Label(window,text='Name',bg='#6495ED',width=15)
   var15label.pack()
   global var15
   var15=StringVar()
   var15Entry=Entry(window,textvariable=var15,width=30).pack()

   var16label=Label(window,text='Address',bg='#6495ED',width=15)
   var16label.pack()
   global var16
   var16=StringVar()
   var16Entry=Entry(window,textvariable=var16,width=30).pack()

   var17label=Label(window,text='Phone Number',bg='#6495ED',width=15)
   var17label.pack()
   global var17
   var17=StringVar()
   var17Entry=Entry(window,textvariable=var17,width=30).pack()

   var18label=Label(window,text='Medicine',bg='#6495ED',width=15)
   var18label.pack()
   global var18
   var18=StringVar()
   var18Entry=Entry(window,textvariable=var18,width=30).pack()

   def insertingpatient():
      con=pymysql.connect(host='localhost',user='root',password="",database='testdb')
      cur=con.cursor()
      cur.execute("INSERT INTO patient (National_ID,Name,Address,Phone_Number,medicine) VALUES (%s, %s, %s,%s,%s)",
      (var14.get(),var15.get(),var16.get(),var17.get(),var18.get()))
      con.commit()
   storeButton = Button(window, text="store", command=insertingpatient,background='#3CB371').pack()
   window.mainloop()





#login

def ok():
    try:
        con=pymysql.connect(host='localhost',user='root',password="",database='testdb')
        cur=con.cursor()
        cur.execute("select * from  login where UserName =%s and Password =%s",(username.get(),password.get()))
        row=cur.fetchone()
        print(row)

        if row==None:
            messagebox.showerror('error',f"invald username or password")
        else:
            menu=Tk()
            menu.geometry('300x250')
            menu.configure(bg = "#093545")
            menu.title('operation')
            
            button1 = Button(menu, text="store drug data", command= insert,background='#3CB371').pack()
            Label(menu,text="",bg="#093545").pack()
            button2 = Button(menu, text="search for drug", command=search,background='#3CB371').pack()
            Label(menu,text="",bg="#093545").pack()
            button3 = Button(menu, text="store employee data", command=Employee,background='#3CB371').pack()
            Label(menu,text="",bg="#093545").pack()
            button4 = Button(menu, text="store patient data", command=Patient,background='#3CB371').pack()            


    except Exception as ex:
        messagebox.showerror('error',f"error due to: {str(ex)}")




window = Tk()
window.geometry('300x250')
window.configure(bg = "#093545")
window.title('log into system')
# the frist line introduction
Label(window, text="log in into the system",width=45, height=1).pack()
Label(window, text="",bg="#093545").pack()
usernamelable=Label(window,text='username',background='#7AC5CD',width=15)
usernamelable.pack()
username = StringVar()
usernameEntry = Entry(window, textvariable=username,width=30)
usernameEntry.pack()
Label(window, text="",bg="#093545").pack()
passwordLabel = Label(window,text="Password",background='#7AC5CD',width=15)
passwordLabel.pack()
password = StringVar()
passwordEntry = Entry(window, textvariable=password, show='*',width=30)
passwordEntry.pack()

Label(window, text="",bg="#093545").pack()

loginButton = Button(window, text="Login", command=ok,background='#3CB371')
loginButton.pack()
#To continue the process till kill
window.mainloop()
# Out:
# ('1', 'mohamed', '123')
